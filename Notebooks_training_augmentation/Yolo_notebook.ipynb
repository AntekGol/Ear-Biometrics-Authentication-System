# %%
# !pip install ultralytics
# !pip install roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YlefvM4jdTLWVM89e3u0")
project = rf.workspace("inz-vxaey").project("uszy-detekcja")
version = project.version(7)
dataset = version.download("yolov8")

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/uszy-detekcja-7/data.yaml",
    epochs=50, #maximum number of epochs
    imgsz=800, #image size
    batch=16, #number of samples
    device=0,
    patience=5,  #Early stopping after 5 epochs without metrics improvement
    save=True,   #Automatically saves the best model
)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 80.1MB/s]
# Ultralytics 8.3.154 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
